# %% [markdown]
# <a href="https://colab.research.google.com/github/amandalutviah/Praktikum-1-Amanda-Lutviah-Putri/blob/main/praktikum_2_amanda_lutviah_putri_2510631330008.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

g = 9.8 #percepatan gravitasi (m**2)
h = 100 #ketinggian awal (m)
Vo = 0 #kecepatan awal (m/s)
dt = 1 #interval waktu (s)
t = list(range(11))
s = [0.5*g*(ti**2) for ti in t]
v = [g* ti for ti in t]
a = [g] * len(t)



plt.plot(t,s, marker='o', label='Posisi')
plt.plot(t,v, marker='o', label='Kecepatan')
plt.plot(t,a, marker='o', label='Percepatan')
plt.title("Grafik posisi vs Waktu: Gerak jatuh bebas")
plt.xlabel("Waktu (detik)")
plt.ylabel("Posisi (m)")
plt.grid(True)
plt.legend()
plt.show()

#Nlai maksimum
print("kasus 1:")
print(f"posisi maksimum: {max(s):.2f}m")
print(f"kecepatan maksimum: {max(v):.2f}m/s")
print(f"percepatan maksimum: {max(a):.2f}m/s²")
# Out:
# kasus 1:
# posisi maksimum: 490.00m
# kecepatan maksimum: 98.00m/s
# percepatan maksimum: 9.80m/s²

# %%
import matplotlib.pyplot as plt

g = 9.8 #percepatan gravitasi (m**2)
h = 120 #ketinggian awal (m)
Vo = 0 #kecepatan awal (m/s)
dt = 0,5 #interval waktu (s)
t = list(range(10))
s = [0.5*g*(ti**2) for ti in t]
v = [g* ti for ti in t]
a = [g] * len(t)



plt.plot(t,s, marker='o', label='Posisi')
plt.plot(t,v, marker='o', label='Kecepatan')
plt.plot(t,a, marker='o', label='Percepatan')
plt.title("Grafik posisi vs Waktu: Gerak jatuh bebas")
plt.xlabel("Waktu (detik)")
plt.ylabel("Posisi (m)")
plt.grid(True)
plt.legend()
plt.show()

#Nlai maksimum
print("kasus 2:")
print(f"posisi maksimum: {max(s):.2f}m")
print(f"kecepatan maksimum: {max(v):.2f}m/s")
print(f"percepatan maksimum: {max(a):.2f}m/s²")
# Out:
# kasus 2:
# posisi maksimum: 396.90m
# kecepatan maksimum: 88.20m/s
# percepatan maksimum: 9.80m/s²

# %%
import matplotlib.pyplot as plt

g = 1.6 #percepatan gravitasi (m**2)
h = 50 #ketinggian awal (m)
Vo = 0 #kecepatan awal (m/s)
dt = 2 #interval waktu (s)
t = list(range(20))
s = [0.5*g*(ti**2) for ti in t]
v = [g* ti for ti in t]
a = [g] * len(t)



plt.plot(t,s, marker='o', label='Posisi')
plt.plot(t,v, marker='o', label='Kecepatan')
plt.plot(t,a, marker='o', label='Percepatan')
plt.title("Grafik posisi vs Waktu: Gerak jatuh bebas")
plt.xlabel("Waktu (detik)")
plt.ylabel("Posisi (m)")
plt.grid(True)
plt.legend()
plt.show()

#Nlai maksimum
print("kasus 3:")
print(f"posisi maksimum: {max(s):.2f}m")
print(f"kecepatan maksimum: {max(v):.2f}m/s")
print(f"percepatan maksimum: {max(a):.2f}m/s²")
# Out:
# kasus 3:
# posisi maksimum: 288.80m
# kecepatan maksimum: 30.40m/s
# percepatan maksimum: 1.60m/s²

# %%
import matplotlib.pyplot as plt

g = 9.8 #percepatan gravitasi (m**2)
h = 500 #ketinggian awal (m)
Vo = 0 #kecepatan awal (m/s)
dt = 2 #interval waktu (s)
t = list(range(20))
s = [0.5*g*(ti**2) for ti in t]
v = [g* ti for ti in t]
a = [g] * len(t)



plt.plot(t,s, marker='o', label='Posisi')
plt.plot(t,v, marker='o', label='Kecepatan')
plt.plot(t,a, marker='o', label='Percepatan')
plt.title("Grafik posisi vs Waktu: Gerak jatuh bebas")
plt.xlabel("Waktu (detik)")
plt.ylabel("Posisi (m)")
plt.grid(True)
plt.legend()
plt.show()

#Nlai maksimum
print("kasus 4:")
print(f"posisi maksimum: {max(s):.2f}m")
print(f"kecepatan maksimum: {max(v):.2f}m/s")
print(f"percepatan maksimum: {max(a):.2f}m/s²")
# Out:
# kasus 4:
# posisi maksimum: 1768.90m
# kecepatan maksimum: 186.20m/s
# percepatan maksimum: 9.80m/s²
